# %% [markdown]
# # 這是第一支程式

# %%
print("hello word")

# %%
# This is a simple program for beginners

# We can store numbers in variables
number1 = 10
number2 = 5

# We can perform calculations with variables
sum_of_numbers = number1 + number2

# We can print the result
print("The first number is:", number1)
print("The second number is:", number2)
print("The sum of the numbers is:", sum_of_numbers)

# %%
x = 10
y = 5

z = x + y
print(z)

# %%
# Emoji 輸出
print('Python 超可愛！ 😍🐍')

# %%
# 互動輸入
name = input('請輸入你的名字：')
print('哈囉，' + name + '，歡迎來到 Python 世界！')

# %%
# 超簡單動畫：跑馬燈效果（來回）
import time
text = 'Python 好好玩！'
width = 10
for i in list(range(width)) + list(range(width - 2, 0, -1)):
    print('\r' + ' ' * i + text, end='')
    time.sleep(0.2)
print()

# %%
# 隨機幸運數字
import random
lucky = random.randint(1, 100)
print('今天的幸運數字是：', lucky)

# %%
# 超簡單圖形：用 * 畫三角形
for i in range(1, 6):
    print('*' * i)
