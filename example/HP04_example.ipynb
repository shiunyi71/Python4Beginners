# %% [markdown]
# # Week 04: 流程控制(上) - 程式的決策之道！
# # Python 程式範例集
#
# 本筆記本包含第四週課程中所有的 Python 程式範例，涵蓋條件判斷、比較運算、邏輯運算等重要概念。
#
# ## 📚 內容目錄
# 1. [基本條件判斷](#基本條件判斷)
# 2. [比較運算符號](#比較運算符號)
# 3. [邏輯運算符號](#邏輯運算符號)
# 4. [多重條件判斷](#多重條件判斷)
# 5. [互動式選單](#互動式選單)
# 6. [Random模組應用](#Random模組應用)
# 7. [綜合實戰範例](#綜合實戰範例)

# %% [markdown]
# ## 基本條件判斷
#
# ### 🌡️ 溫度判斷範例

# %%
# 基本 if-else 條件判斷
temperature = int(input("今天溫度是幾度？"))

if temperature >= 25:
    print("今天很熱，記得多喝水！🌞")
else:
    print("今天涼爽，適合出門走走！🚶‍♂️")

# %% [markdown]
# ## 比較運算符號
#
# ### 🎯 實戰練習

# %%
# 單向判斷 (單選，有符合就執行，沒有符合就什麼都不發生)
score = 85

# 基本比較運算
print(score >= 80)    # True
print(score == 100)   # False

# 結合if條件判斷
if score >= 80:
    print("恭喜！成績優良！🎉")

if score != 100:
    print("還有進步空間喔！💪")

# 更多比較範例
age = 18
if age >= 18:
    print("已成年，可以投票！🗳️")

temperature = 26
if temperature > 25:
    print("今天很熱！🌞")

# %%
# 雙向判斷 (二選一)

score = 100

# 基本比較運算
print(score >= 80)    # True
print(score == 100)   # False

# 結合if條件判斷
if score >= 80:
    print("恭喜！成績優良！🎉")
    print("今天吃大餐！")
else:
    print("加油！")

if score != 100:
    print("還有進步空間喔！💪")
else:
    print("100分好棒棒！")

# 更多比較範例
age = 2
if age >= 18:
    print("已成年，可以投票！🗳️")
else:
    print("未成年，再等等")

temperature = 21
if temperature > 25:
    print("今天很熱！🌞")
else:
    print("天氣不錯！")

# %% [markdown]
# ## 邏輯運算符號
#
# ### 🎓 成績分級範例

# %%
# 多選一(多個選擇中，只會符合一個)
score = int(input("請輸入成績："))

if score >= 90 and score <= 100:
    print("A級：優秀！🏆")
elif score >= 80 and score < 90:
    print("B級：良好！👍")
elif score >= 70 and score < 80:
    print("C級：及格！✅")
else:
    print("需要加油！💪")

# %%
# 簡化寫法
score = int(input("請輸入成績："))

# if elif 是多選一
if score >= 90:
    print("A級：優秀！🏆")
elif score >= 80:
    print("B級：良好！👍")
elif score >= 70:
    print("C級：及格！✅")
else:
    print("需要加油！💪")

# %%
# 生成像這樣的程式只需要把規則(條件)說清楚就好
# 請幫我寫一支程式，判斷使用者輸入的分數，90以上是A，80以上是B，70以上是C，剩下的則需要加油

# %% [markdown]
# ## 多重條件判斷
#
# ### 🚦 交通燈號系統

# %%
light = input("交通號誌是什麼顏色？(紅/黃/綠)")

if light == "紅":
    print("🔴 停止！等待綠燈")
elif light == "黃":
    print("🟡 準備停車，注意安全")
elif light == "綠":
    print("🟢 可以通行")
else:
    print("❓ 無效的號誌顏色")

# %% [markdown]
# ## 互動式選單
#
# ### 🍕 Pizza店選單系統

# %%
print("=== 🍕 歡迎來到Pizza店 ===")
print("1. 瑪格麗特披薩 - $280")
print("2. 夏威夷披薩 - $320")
print("3. 海鮮披薩 - $380")
print("4. 離開")

choice = input("請選擇您要的披薩(1-4)：")

if choice == "1":
    print("您選擇了瑪格麗特披薩！🍕")
elif choice == "2":
    print("您選擇了夏威夷披薩！🍍")
elif choice == "3":
    print("您選擇了海鮮披薩！🦐")
elif choice == "4":
    print("謝謝光臨！👋")
else:
    print("無效選擇，請重新選擇！")

# %%
# 請幫我寫一個Pizza店的點餐程式，需要顯示披薩菜單和價格，讓使用者輸入選擇(1-4)，然後根據選擇顯示不同的訊息。如果使用者選擇4，則顯示謝謝光臨。如果輸入無效的選擇，也要有提示。
'''
**菜單：**
1. 瑪格麗特披薩 - $280
2. 夏威夷披薩 - $320
3. 海鮮披薩 - $380
4. 離開
'''

# %% [markdown]
# ### 📚 學生成績管理系統

# %%
# 請生成一支Python程式為學生的成績管理系統
# 使用者可以輸入國英數三科的成績
# 接著計算這三科的總分和平均然後印出來
# 然後在判斷平均分數的等第
# 90分以上是A, 80分以上是B, 以此類推一直到E
# 並且在印出每個等第之後，加上鼓勵的標語

# %%
print("=== 📚 學生成績管理系統 ===")

# 輸入國文、英文和數學成績
# Prompt the user to input scores for Chinese, English, and Math
chinese = int(input("請輸入國文成績："))
english = int(input("請輸入英文成績："))
math = int(input("請輸入數學成績："))

# 計算總分和平均
# Calculate the total and average scores
total = chinese + english + math
average = total / 3

# 顯示總分和平均分
# Display the total and average scores
print(f"總分：{total}")
print(f"平均：{average:.1f}")

# 根據平均分數判斷成績等級
# Determine the grade level based on the average score
if average >= 90:
    print("🏆 A級：優秀！")
    print("建議：繼續保持！")
elif average >= 80:
    print("👍 B級：良好！")
    print("建議：再接再厲！")
# ...末完待補完
else:
    print("💪 E級：需努力！")
    print("建議：尋求老師或同學協助！")

# %% [markdown]
# ## Random模組應用
#
# ### 基本Random函式使用

# %%
import random

# 1. random.randint(a, b) - 產生整數範圍隨機數
dice = random.randint(1, 6)    # 骰子
lottery = random.randint(1, 49) # 樂透號碼
print(f"骰子點數：{dice}")
print(f"樂透號碼：{lottery}")

# 2. random.choice(sequence) - 從序列中隨機選擇
colors = "紅色", "藍色", "綠色", "黃色", "紫色"
chosen_color = random.choice(colors)
print(f"隨機顏色：{chosen_color}")

activities = ["看電影", "運動", "讀書", "購物"]
today_plan = random.choice(activities)
print(f"今日計畫：{today_plan}")

# 3. random.random() - 產生0-1之間的小數
probability = random.random()
print(f"機率值：{probability}")

# 模擬擲硬幣
if random.random() > 0.5:
    print("正面！")
else:
    print("反面！")

# 4. random.shuffle(list) - 打亂清單順序
cards = ["A", "K", "Q", "J", "10"]
print(f"原始順序：{cards}")
random.shuffle(cards)
print(f"洗牌後：{cards}")

# %%
# 讓AI生成隨機數，只要清楚地說出你的需求就可以了
# 比如說樂透就跟他說：請生成6個隨機數，範圍是1到49之間而且每個數字不能重複

# %% [markdown]
# ### 🎯 猜數字遊戲

# %%
# 請生成一隻猜數字遊戲常識一開始隨機一數字範圍為1到1百之間
# 使用者可以輸入一數字進行猜測猜對或猜錯都立即公布答案

# %%
import random

secret = random.randint(1, 100)
# print(secret)
guess = int(input("猜一個1-100的數字："))

if guess == secret:
    print("🎉 恭喜！猜對了！")
elif guess > secret:
    print("📉 太大了！")
else:
    print("📈 太小了！")
print('答案是',secret)

# %% [markdown]
# ### 🔮 運勢占卜器

# %%
import random

print("🔮 今日運勢占卜器 🔮")
name = input("請輸入您的姓名：")

# 隨機運勢
fortunes = [
    "大吉！今天是你的幸運日！🍀",
    "中吉！保持積極心態！😊",
    "小吉！會有小驚喜等著你！✨",
    "平！平平淡淡也是福！😌",
    "凶！小心謹慎，避免衝動！⚠️"
]

# 隨機幸運數字
lucky_number = random.randint(1, 99)

# 隨機幸運顏色
lucky_colors = ["紅色", "藍色", "綠色", "黃色", "紫色", "粉色"]
lucky_color = random.choice(lucky_colors)

print(f"\n{name}，您今日的運勢是：")
print(random.choice(fortunes))
print(f"幸運數字：{lucky_number}")
print(f"幸運顏色：{lucky_color}")

# %% [markdown]
# ### 🎮 猜數字進階版

# %%
# 請生成一隻猜數字遊戲程式一開始隨機一數字範圍為1到100之間
# 使用者可以輸入一數字進行猜測
# 若是猜得比答案大就說：太大了猜小一點。反之亦然
# 重複直到猜中為止
# (同學們要是有什麼有趣的想法，比如說次數限制也可以加在裡面)

# %%
import random

print("🎯 猜數字遊戲 🎯")
secret_number = random.randint(1, 100)
attempts = 0
max_attempts = 7

print("我想了一個1到100的數字，你能猜到嗎？")
print(f"你有{max_attempts}次機會！")

while attempts < max_attempts:
    guess = int(input(f"第{attempts + 1}次猜測："))
    attempts += 1

    if guess == secret_number:
        print(f"🎉 太棒了！你猜對了！答案就是{secret_number}")
        print(f"你總共猜了{attempts}次！")
        break
    elif guess > secret_number:
        print("📉 太大了！再試試看！")
    else:
        print("📈 太小了！再試試看！")

    remaining = max_attempts - attempts
    if remaining > 0:
        print(f"還有{remaining}次機會！")
    else:
        print(f"😭 遊戲結束！答案是{secret_number}")

# %% [markdown]
# ## 綜合實戰範例
#
# ### 🤖 智慧選擇器：今天吃什麼決策器

# %%
# 請思考下方邏輯何者有錯？為什麼錯？

# 請撰寫一個智慧選擇程式
# 讓使用者輸入今天的心情開心難過或是普通
# 接著讓使用者輸入預算
# 如果心情是開心"或者"預算大於500都可以在高級日料法式餐廳牛排排管之中隨機選一個
# 但如果心情是開心預算卻低於500的話就只能從火鍋燒烤於義大利麵中隨機選一個
# 如果心情是難過的話就只能泡麵冰淇淋炸雞三選一
# 如果既不是開心也不是難過那就看預算了如果預算大於500就吃：隨便日料、假法式餐廳跟臺式牛排館三選一
# 同樣不是開心也不是難過的情況下，若預算低於500那就只能吃便當面店跟自助餐

# %%
import random

print("🍽️ === 智慧選擇器：今天吃什麼？ ===")
mood = input("你今天心情如何？(開心/難過/普通)：")
budget = int(input("預算多少錢？"))

if mood == "開心" or budget >= 500: #經典羅輯錯誤！
    foods = ["高級日料", "法式餐廳", "牛排館"]
elif mood == "開心" and budget < 500:
    foods = ["火鍋", "燒烤", "義大利麵"]
elif mood == "難過":
    foods = ["泡麵", "冰淇淋", "炸雞"]
else:
  if budget >= 500:
      foods = ["隨便日料", "假、法式餐廳", "台式牛排館"]
  else:
      foods = ["便當", "麵店", "自助餐"]

choice = random.choice(foods)
print(f"🎯 建議你今天吃：{choice}")

if budget >= 300:
    print("💰 預算充足，好好享受吧！")
else:
    print("💡 省錢也能吃得開心！")

# %%
# 邏輯修正版

# 請撰寫一個智慧選擇程式
# 讓使用者輸入今天的心情開心難過或是普通
# 接著讓使用者輸入預算
# 如果心情是開心而且預算大於500都可以在高級日料法式餐廳牛排排管之中隨機選一個
# 但如果心情是開心預算卻低於500的話就只能從火鍋燒烤於義大利麵中隨機選一個
# 如果心情是難過的話就只能泡麵冰淇淋炸雞三選一
# 如果既不是開心也不是難過那就看預算了如果預算大於500就吃：隨便日料、假法式餐廳跟臺式牛排館三選一
# 同樣不是開心也不是難過的情況下，若預算低於500那就只能吃便當面店跟自助餐

# %% [markdown]
# ### 💡 電影推薦系統（作業選項二範例）
#
#
# - 同學們可以思考一下用什麼樣的提示詞(prompt)可以產生像這樣子的程式
# - 可以產生一支屬於自己的推薦系統喔！

# %%
# 電影推薦系統範例架構
# 學生可以基於這個架構完成完整系統

import random

print("🎬 === 智慧電影推薦系統 ===")

# 1. 輸入使用者喜好
genre = input("你喜歡什麼類型的電影？(動作/愛情/喜劇/科幻)：")
time = int(input("你有多少時間看電影？(分鐘)："))
mood = input("你今天心情如何？(開心/放鬆/緊張)：")

# 2. 根據類型和時間推薦
if genre == "動作" and time >= 120:
    movies = ["復仇者聯盟", "變形金剛", "不可能的任務"]
elif genre == "動作" and time < 120:
    movies = ["玩命關頭", "限制級戰警", "追殺比爾"]
elif genre == "愛情" and time >= 120:
    movies = ["鐵達尼號", "真愛每一天", "手札情緣"]
elif genre == "愛情" and time < 120:
    movies = ["真愛至上", "戀夏500日", "愛是您愛是我"]
elif genre == "喜劇":
    movies = ["功夫", "國產凌凌漆", "金雞"]
elif genre == "科幻":
    movies = ["星際大戰", "駭客任務", "全面啟動"]
else:
    movies = ["阿甘正傳", "肖申克的救贖", "教父"]

# 3. 隨機推薦
recommendation = random.choice(movies)
print(f"\n🎯 推薦電影：{recommendation}")

# 4. 額外建議
if mood == "緊張":
    print("💡 建議選擇輕鬆的類型放鬆一下！")
elif time < 90:
    print("⏰ 時間不多，建議選擇短片或紀錄片！")
else:
    print("🍿 準備好爆米花，享受電影時光吧！")

# %% [markdown]
# ---
#
# ## 📝 練習作業參考
#
# 以上範例涵蓋了第四週課程的所有重要概念：
#
# ### ✅ 學習檢核清單
# - [x] **基本條件判斷** - if/else 語法
# - [x] **比較運算符號** - ==, !=, >, <, >=, <=
# - [x] **邏輯運算符號** - and, or, not
# - [x] **多重條件判斷** - elif 結構
# - [x] **互動式選單** - 使用者輸入處理
# - [x] **Random模組** - 隨機數生成與選擇
# - [x] **綜合應用** - 實際問題解決
#
# ### 🚀 進階挑戰
# 1. 修改現有範例，加入更多功能
# 2. 結合多個概念創造新的應用
# 3. 加入錯誤處理機制
# 4. 美化使用者介面輸出
#
# ### 💪 作業提示
# - **基礎練習**：從學生成績管理系統開始
# - **進階應用**：整合智慧選擇決策系統
# - **創意發揮**：設計個人化智慧助手
#
# 記得在實作時加入充分的註解，讓程式碼更容易理解！
