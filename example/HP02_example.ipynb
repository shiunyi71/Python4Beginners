# %% [markdown]
# # 經典的開始

# %%
print("Hello, World!")
print("歡迎來到Python的世界！")
# Out:
# Hello, World!
# 歡迎來到Python的世界！

# %% [markdown]
# ### print() 函數

# %%
print('這是文字')
print(123)                # 數字
print("我今年", 20, "歲")  # 混合輸出
# Out:
# 這是文字
# 123
# 我今年 20 歲

# %%
name = input("請輸入你的名字：")
age = input("請輸入你的年齡：")
print("哈囉", name, "！你今年", age, "歲")
# Out:
# 請輸入你的名字：小明
# 請輸入你的年齡：18
# 哈囉 小明 ！你今年 18 歲

# %% [markdown]
# ### 實際互動範例

# %%
# 簡單的自我介紹程式
print("=== 自我介紹小程式 ===")
name = input("你的名字是？")
hobby = input("你的興趣是？")

print("\n很高興認識你！")
print(f"姓名：{name}")
print(f"興趣：{hobby}")
print("歡迎加入Python學習行列！🎉")
# Out:
# === 自我介紹小程式 ===
# 你的名字是？大明
# 你的興趣是？打球
#
# 很高興認識你！
# 姓名：大明
# 興趣：打球
# 歡迎加入Python學習行列！🎉

# %% [markdown]
# ## 用print畫出炫酷圖案
#
# ### ASCII藝術基礎

# %%
print("  *  ")
print(" *** ")
print("*****")
print(" *** ")
print("  *  ")
# Out:
#   *
#  ***
# *****
#  ***
#   *

# %%
# 使用emoji裝飾
print("🌟 Python學習之旅 🌟")
print("  ⭐ 歡迎來到程式世界 ⭐")

# 混合ASCII與emoji
print("   🐍")
print("   /|\\ ")
print("   / \\ ")
print("Python小蛇")
# Out:
# 🌟 Python學習之旅 🌟
#   ⭐ 歡迎來到程式世界 ⭐
#    🐍
#    /|\
#    / \
# Python小蛇

# %% [markdown]
# ### 繪製愛心 💝

# %%
print("  ❤️   ❤️  ")
print(" ❤️ ❤️ ❤️ ❤️ ")
print("❤️  ❤️ ❤️  ❤️")
print(" ❤️  ❤️  ❤️ ")
print("  ❤️   ❤️  ")
print("   ❤️ ❤️   ")
print("    ❤️    ")
# Out:
#   ❤️   ❤️
#  ❤️ ❤️ ❤️ ❤️
# ❤️  ❤️ ❤️  ❤️
#  ❤️  ❤️  ❤️
#   ❤️   ❤️
#    ❤️ ❤️
#     ❤️

# %%
print("  ❤️ ❤️  ")
print(" ❤️❤️❤️ ")
print("❤️❤️❤️❤️")
print(" ❤️❤️❤️ ")
print("  ❤️❤️  ")
print("   ❤️   ")
# Out:
#   ❤️ ❤️
#  ❤️❤️❤️
# ❤️❤️❤️❤️
#  ❤️❤️❤️
#   ❤️❤️
#    ❤️

# %% [markdown]
# ### 繪製聖誕樹 🎄

# %%
print("      *      ")
print("     ***     ")
print("    *****    ")
print("   *******   ")
print("  *********  ")
print(" *********** ")
print("*************")
print("     |||     ")
print("     |||     ")
print("=== 聖誕快樂 ===")
# Out:
#       *
#      ***
#     *****
#    *******
#   *********
#  ***********
# *************
#      |||
#      |||
# === 聖誕快樂 ===

# %% [markdown]
# ### 用Python程式碼繪製一隻ASCII小貓
# #### 基本小貓圖案 🐱

# %%
print("     /\\_/\\  ")
print("    ( o.o ) ")
print("     > ^ <  ")
print("    _______")
print("   |       |")
print("   | MEOW! |")
print("   |_______|")
# Out:
#      /\_/\
#     ( o.o )
#      > ^ <
#     _______
#    |       |
#    | MEOW! |
#    |_______|

# %% [markdown]
# ## 跨行字串 - 多行文字的優雅處理

# %%
# 使用三重引號處理多行文字
"""
  沒存到變數中，就會變成註解。
  這是第一行註解。
  這是第二行註解。
"""
multi_line_text = """
  歡迎來到Python世界！
  這是第二行文字
  這是第三行文字
  程式設計真有趣！
"""
print(multi_line_text)
# Out:
#   歡迎來到Python世界！
#   這是第二行文字
#   這是第三行文字
#   程式設計真有趣！

# %%
message = "第一行\t第二行\n第三行"
print(message)
# Out:
# 第一行	第二行
# 第三行

# %%
# 用三重引號建立ASCII藝術
cat_ascii = """
   /\\_/\\
  ( o.o )
   > ^ <
  _______
  |       |
  | MEOW! |
  |_______|
"""

print("可愛的小貓咪：")
print(cat_ascii)
# Out:
# 可愛的小貓咪：
#
#    /\_/\
#   ( o.o )
#    > ^ <
#   _______
#   |       |
#   | MEOW! |
#   |_______|

# %%
cat = r"""
                                                 .===.
                                               .+%%%%#
                                               *%####-
                                              =####*+
                                              ####**=
                                             -###*+#:
                                             +###*+*
                                             *###**-
                                             ####*+:        .:-=====-:.
                                            .####*+:     :=*****##*****+=.
                                           :+###***:. :=**##%%%#*+++++**##+.
                                         .::+##****-::-###*************#*#**=
                                        .:::*###***+=+%%#+***********########*.
                                       .:::+######**#%%#**###********##*#######:
                                      .-:=*##**##**##%%#*#%#***#*+*#*#***#######-
                                     .-:=***=-+######%#**###**#+-:-=**###*#**##%#:
                                    .-=+***-:-**#***#%#####*+=:...:::=**####*####*.
                                    -=*#*+-:=******+*#%%##*=-:::....:::=**#######%=
                                   ::*#*=::-***#++=+*#%%%%#*--::::....::-*#*#*#####
                                  .:-*#=:::+###*+*#*########=-:::.......:=#**####*#.
                                 .:-*#*:::-*#***#%%#*#**###*=--:::....::--****#####.
                                .::=**=:::+#**+=#%%#****##*+=----:::::---+***#####*
                               .:.:+*=:::-**#*++##%#***+**++------::----=**#######=
                             ....:=+=-::-*###*+=+*##*#*+*+==-------:-===++*###**##-
                            :::..:+=----=###*+=+*******++=--------==--+*+++*##**##.
                           :::::::----:-+#***+++*+****++=--:::::--===*#**++*#****=
                           =-::::::-----=###*+++*+**+++=--:..::--==+##***********:
                           ==-:::::=----=**##*++****+==--:..::---=*####*********#.
                           .+=-::::=++**+**###*+++++=---:...:---=*#####**********
                            -++=-::=++*+*******+++==-::....:---=######*****+*###=
                             .-+==--++****++***++=-::.....:---=####********###++
                               :========+======--::......:---=**#***++**+++***=.
                                 :==++==----:::::::.....---==*****+++++===+*-.
                                   -=++=-:::::::::.:..:----=+*#****++=---++:
                                    .-===--:::::::::::-=-==*#####**+==--==-
                                       -+===-::::::::----=#####**+======--
                                       =***===--:::---===*******++=-=-::.
                                       .::. :====--=====*+==+++.
                                              .::--::...#*+++=-
                                                       .*++*=-.
                                                        --:.

"""
print(cat)
# Out:
#                                                  .===.
#                                                .+%%%%#
#                                                *%####-
#                                               =####*+
#                                               ####**=
#                                              -###*+#:
#                                              +###*+*
#                                              *###**-
#                                              ####*+:        .:-=====-:.
#                                             .####*+:     :=*****##*****+=.
#                                            :+###***:. :=**##%%%#*+++++**##+.
#                                          .::+##****-::-###*************#*#**=
#                                         .:::*###***+=+%%#+***********########*.
#                                        .:::+######**#%%#**###********##*#######:
#                                       .-:=*##**##**##%%#*#%#***#*+*#*#***#######-
#                                      .-:=***=-+######%#**###**#+-:-=**###*#**##%#:
#                                     .-=+***-:-**#***#%#####*+=:...:::=**####*####*.
#                                     -=*#*+-:=******+*#%%##*=-:::....:::=**#######%=
#                                    ::*#*=::-***#++=+*#%%%%#*--::::....::-*#*#*#####
#                                   .:-*#=:::+###*+*#*########=-:::.......:=#**####*#.
#                                  .:-*#*:::-*#***#%%#*#**###*=--:::....::--****#####.
#                                 .::=**=:::+#**+=#%%#****##*+=----:::::---+***#####*
#                                .:.:+*=:::-**#*++##%#***+**++------::----=**#######=
#                              ....:=+=-::-*###*+=+*##*#*+*+==-------:-===++*###**##-
#                             :::..:+=----=###*+=+*******++=--------==--+*+++*##**##.
#                            :::::::----:-+#***+++*+****++=--:::::--===*#**++*#****=
#                            =-::::::-----=###*+++*+**+++=--:..::--==+##***********:
#                            ==-:::::=----=**##*++****+==--:..::---=*####*********#.
#                            .+=-::::=++**+**###*+++++=---:...:---=*#####**********
#                             -++=-::=++*+*******+++==-::....:---=######*****+*###=
#                              .-+==--++****++***++=-::.....:---=####********###++
#                                :========+======--::......:---=**#***++**+++***=.
#                                  :==++==----:::::::.....---==*****+++++===+*-.
#                                    -=++=-:::::::::.:..:----=+*#****++=---++:
#                                     .-===--:::::::::::-=-==*#####**+==--==-
#                                        -+===-::::::::----=#####**+======--
#                                        =***===--:::---===*******++=-=-::.
#                                        .::. :====--=====*+==+++.
#                                               .::--::...#*+++=-
#                                                        .*++*=-.
#                                                         --:.

# %%
w = """

        ,--,
      ,--.'|            ,--,    ,--,                               .---.                     ,--,
   ,--,  | :          ,--.'|  ,--.'|                              /. ./|                   ,--.'|         ,---,
,---.'|  : '          |  | :  |  | :     ,---.                .--'.  ' ;   ,---.    __  ,-.|  | :       ,---.'|
|   | : _' |          :  : '  :  : '    '   ,'\              /__./ \ : |  '   ,'\ ,' ,'/ /|:  : '       |   | :
:   : |.'  |   ,---.  |  ' |  |  ' |   /   /   |         .--'.  '   \' . /   /   |'  | |' ||  ' |       |   | |
|   ' '  ; :  /     \ '  | |  '  | |  .   ; ,. :        /___/ \ |    ' '.   ; ,. :|  |   ,''  | |     ,--.__| |
'   |  .'. | /    /  ||  | :  |  | :  '   | |: :        ;   \  \;      :'   | |: :'  :  /  |  | :    /   ,'   |
|   | :  | '.    ' / |'  : |__'  : |__'   | .; :         \   ;  `      |'   | .; :|  | '   '  : |__ .   '  /  |
'   : |  : ;'   ;   /||  | '.'|  | '.'|   :    |          .   \    .\  ;|   :    |;  : |   |  | '.'|'   ; |:  |
|   | '  ,/ '   |  / |;  :    ;  :    ;\   \  /            \   \   ' \ | \   \  / |  , ;   ;  :    ;|   | '/  '
;   : ;--'  |   :    ||  ,   /|  ,   /  `----'              :   '  |--"   `----'   ---'    |  ,   / |   :    :|
|   ,/       \   \  /  ---`-'  ---`-'                        \   \ ;                        ---`-'   \   \  /
'---'         `----'                                          '---"                                   `----'

"""
print(w)
# Out:
#
#         ,--,
#       ,--.'|            ,--,    ,--,                               .---.                     ,--,
#    ,--,  | :          ,--.'|  ,--.'|                              /. ./|                   ,--.'|         ,---,
# ,---.'|  : '          |  | :  |  | :     ,---.                .--'.  ' ;   ,---.    __  ,-.|  | :       ,---.'|
# |   | : _' |          :  : '  :  : '    '   ,'\              /__./ \ : |  '   ,'\ ,' ,'/ /|:  : '       |   | :
# :   : |.'  |   ,---.  |  ' |  |  ' |   /   /   |         .--'.  '   ' . /   /   |'  | |' ||  ' |       |   | |
# |   ' '  ; :  /     \ '  | |  '  | |  .   ; ,. :        /___/ \ |    ' '.   ; ,. :|  |   ,''  | |     ,--.__| |
# '   |  .'. | /    /  ||  | :  |  | :  '   | |: :        ;   \  \;      :'   | |: :'  :  /  |  | :    /   ,'   |
# |   | :  | '.    ' / |'  : |__'  : |__'   | .; :         \   ;  `      |'   | .; :|  | '   '  : |__ .   '  /  |
# '   : |  : ;'   ;   /||  | '.'|  | '.'|   :    |          .   \    .\  ;|   :    |;  : |   |  | '.'|'   ; |:  |
# |   | '  ,/ '   |  / |;  :    ;  :    ;\   \  /            \   \   ' \ | \   \  / |  , ;   ;  :    ;|   | '/  '
# ;   : ;--'  |   :    ||  ,   /|  ,   /  `----'              :   '  |--"   `----'   ---'    |  ,   / |   :    :|
# |   ,/       \   \  /  ---`-'  ---`-'                        \   \ ;                        ---`-'   \   \  /
# '---'         `----'                                          '---"                                   `----'
# <>:7: SyntaxWarning: invalid escape sequence '\ '
# <>:7: SyntaxWarning: invalid escape sequence '\ '
# /tmp/ipython-input-359953293.py:7: SyntaxWarning: invalid escape sequence '\ '
#   |   | : _' |          :  : '  :  : '    '   ,'\              /__./ \ : |  '   ,'\ ,' ,'/ /|:  : '       |   | :

# %%
w = '''











                                                        #%%%@@
                                                     %%#*****#%@
                                                    %#**********%@
                                                   %**************@%
                                                  @******#%%#*****#@
                                                 %@%####@@#@@%%%%##@@
                                                 @#*####@% =@@#-#%%@@
                         .                       @=     -#@@@*     *@
                          +@@@@                   #       .-       %.
                           %@@@@@@                 -             .=@                    @@@@@@
                             @@@@@=+%+              #-.       .-*@                %@%#%@@@@@@
                              @@@=...:+%              @%#*##%%@                @@*=:..+@@@@
                               @+.......-*@      +@@%#*#####%%%@@@%         +@#=......*@@
                               %#.........:+@  *=-:..............::-+#     %*:......-%@.
                                @*..........:-..........................  .........+@@
                                 @*...............................................*@%
                                   #:...........................................:%@
                                     ...........................................%@
                                      ..........................................
                                   %@-...........................................
                                  +@-.............................................#@
                                  @=..............................................:%@
                                 @#................................................-@
                                 @-............:*%#%+...............*%%#=...........+@
                @@%%@@@         @#.............*@@-*@-.............*@*:@@=..........:%%
                @#...:-=*#@%    @:.............#@@@@@-.............+@@@@@-...........=@
               %@-........:-=  @#..............:+##+:...............=%@#-.............#@
               @%.............*@+.......:-+*+=:...........:%%:..............-=++-:....+@
               @*.............%@:......-******+:........:..:-...-=........:+*****+:...-@
               @=............:@%.......********-.......*#:-+*+--@%........+*******+....@%
              @@:............-@#.......-******=........:*%%*+#%%#-........=*******-....%@
              @%.............=@#........-=++=:............................:+*****=.....%@
              @#.............=@*...........................................:-=+=-......#@
              @#.............-@#.......................................................%@
              @#..............@#.......................................................%.
              @#..............#@ .....................................................:@
              @%-:............=@+.....................................................=@%@
                 %%*+-........:++.........................:::::........................:.:*@
                      @#+:..-#@%...........................:::.........................-...+@
                           +@%-.......................................................+@#:..@@
                           @@:........................................................=%#:..@+
                           @@:..-+:..................................................*@=...+@
                          .%@*..-#@+.................................................=@-.:*@
                         @.-@@=...=@#:................................................*@.
                        @#..:%@*-::#@-.................................................%
                        @=....=*%%#*=..................................................%
                       @%..............................................................#
                        @#++=:....:-=..................................................#
                             @%:=**#@*.................................................%
                             @#+####%@#...............................................-@        +%#+       *
                             @#######%@*..............................................*+        %%:%% :@: =@=
                                 @%%   @*:...........................................-@         @@%@* .=  :@=   #=
                                        @%:.........................................=@         -@+    *@: #@@%+ +@@
                                          %-......................................-*@           *     #%  %%.%=-@%@%
                                           @:...............................::..:*@                        -     -+=
                                           #......................:--==+*#%@@*.:%@
                                          *..:+#%%%%##########%%%@@+       @*:.#@
                                        +#..-%                            @+..*@
                                         @#*+                              #+%.











'''
print(w)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#                                                         #%%%@@
#                                                      %%#*****#%@
#                                                     %#**********%@
#                                                    %**************@%
#                                                   @******#%%#*****#@
#                                                  %@%####@@#@@%%%%##@@
#                                                  @#*####@% =@@#-#%%@@
#                          .                       @=     -#@@@*     *@
#                           +@@@@                   #       .-       %.
#                            %@@@@@@                 -             .=@                    @@@@@@
#                              @@@@@=+%+              #-.       .-*@                %@%#%@@@@@@
#                               @@@=...:+%              @%#*##%%@                @@*=:..+@@@@
#                                @+.......-*@      +@@%#*#####%%%@@@%         +@#=......*@@
#                                %#.........:+@  *=-:..............::-+#     %*:......-%@.
#                                 @*..........:-..........................  .........+@@
#                                  @*...............................................*@%
#                                    #:...........................................:%@
#                                      ...........................................%@
#                                       ..........................................
#                                    %@-...........................................
#                                   +@-.............................................#@
#                                   @=..............................................:%@
#                                  @#................................................-@
#                                  @-............:*%#%+...............*%%#=...........+@
#                 @@%%@@@         @#.............*@@-*@-.............*@*:@@=..........:%%
#                 @#...:-=*#@%    @:.............#@@@@@-.............+@@@@@-...........=@
#                %@-........:-=  @#..............:+##+:...............=%@#-.............#@
#                @%.............*@+.......:-+*+=:...........:%%:..............-=++-:....+@
#                @*.............%@:......-******+:........:..:-...-=........:+*****+:...-@
#                @=............:@%.......********-.......*#:-+*+--@%........+*******+....@%
#               @@:............-@#.......-******=........:*%%*+#%%#-........=*******-....%@
#               @%.............=@#........-=++=:............................:+*****=.....%@
#               @#.............=@*...........................................:-=+=-......#@
#               @#.............-@#.......................................................%@
#               @#..............@#.......................................................%.
#               @#..............#@ .....................................................:@
#               @%-:............=@+.....................................................=@%@
#                  %%*+-........:++.........................:::::........................:.:*@
#                       @#+:..-#@%...........................:::.........................-...+@
#                            +@%-.......................................................+@#:..@@
#                            @@:........................................................=%#:..@+
#                            @@:..-+:..................................................*@=...+@
#                           .%@*..-#@+.................................................=@-.:*@
#                          @.-@@=...=@#:................................................*@.
#                         @#..:%@*-::#@-.................................................%
#                         @=....=*%%#*=..................................................%
#                        @%..............................................................#
#                         @#++=:....:-=..................................................#
#                              @%:=**#@*.................................................%
#                              @#+####%@#...............................................-@        +%#+       *
#                              @#######%@*..............................................*+        %%:%% :@: =@=
#                                  @%%   @*:...........................................-@         @@%@* .=  :@=   #=
#                                         @%:.........................................=@         -@+    *@: #@@%+ +@@
#                                           %-......................................-*@           *     #%  %%.%=-@%@%
#                                            @:...............................::..:*@                        -     -+=
#                                            #......................:--==+*#%@@*.:%@
#                                           *..:+#%%%%##########%%%@@+       @*:.#@
#                                         +#..-%                            @+..*@
#                                          @#*+                              #+%.

# %% [markdown]
# ## Time套件基本應用
#
# ### 匯入時間模組

# %%
import time

# 獲取當前時間
current_time = time.time()
print("目前時間戳：", current_time)

print(time.localtime(current_time))
print(time.gmtime(current_time))

# 格式化時間顯示
formatted_time = time.strftime("%Y-%m-%d %H:%M:%S")
print("現在時間：", formatted_time)
# Out:
# 目前時間戳： 1757387910.0776055
# time.struct_time(tm_year=2025, tm_mon=9, tm_mday=9, tm_hour=3, tm_min=18, tm_sec=30, tm_wday=1, tm_yday=252, tm_isdst=0)
# time.struct_time(tm_year=2025, tm_mon=9, tm_mday=9, tm_hour=3, tm_min=18, tm_sec=30, tm_wday=1, tm_yday=252, tm_isdst=0)
# 現在時間： 2025-09-09 03:18:30

# %% [markdown]
# ### time模組基本功能介紹
#
# #### 1. 基本時間函數

# %%
import time

# 獲取當前時間戳（從1970年1月1日開始的秒數）
timestamp = time.time()
print(f"時間戳：{timestamp}")

# 暫停程式執行
print("準備暫停3秒...")
time.sleep(3)
print("暫停結束！")

timestamp2 = time.time()
print(f"時間戳：{timestamp2}")

print('用了：', timestamp2-timestamp)
# Out:
# 時間戳：1757388153.3700523
# 準備暫停3秒...
# 暫停結束！
# 時間戳：1757388156.3711865
# 用了： 3.001134157180786

# %%
import time

print("準備暫停3秒...")

# 獲取當前時間戳（從1970年1月1日開始的秒數）
timestamp = time.time()
print(f"時間戳：{timestamp}")

# 暫停程式執行
time.sleep(3)

timestamp2 = time.time()
print(f"時間戳：{timestamp2}")
print('用了：', timestamp2-timestamp)

print("暫停結束！")
# Out:
# 準備暫停3秒...
# 時間戳：1757388144.3679028
# 時間戳：1757388147.3684032
# 用了： 3.000500440597534
# 暫停結束！

# %% [markdown]
# #### 2. 時間格式化顯示

# %%
import time

# 格式化當前時間
current_time = time.strftime("%Y年%m月%d日 %H:%M:%S")
print(f"現在時間：{current_time}")

# 不同的時間格式
print("年-月-日：", time.strftime("%Y-%m-%d"))
print("時:分:秒：", time.strftime("%H:%M:%S"))
print("星期幾：", time.strftime("%A"))
# Out:
# 現在時間：2025年09月09日 03:23:11
# 年-月-日： 2025-09-09
# 時:分:秒： 03:23:11
# 星期幾： Tuesday

# %% [markdown]
# #### 3. 計時器應用

# %%
import time

def simple_timer(seconds):
    for i in range(seconds, 0, -1):
        print(f"倒數：{i} 秒")
        time.sleep(1)
    print("時間到！⏰")

# 使用計時器
simple_timer(5)
# Out:
# 倒數：5 秒
# 倒數：4 秒
# 倒數：3 秒
# 倒數：2 秒
# 倒數：1 秒
# 時間到！⏰

# %% [markdown]
# #### 4. 程式執行時間測量

# %%
import time

start_time = time.time()

# 模擬一些工作
for i in range(1000000):
    pass

end_time = time.time()
execution_time = end_time - start_time
print(f"程式執行時間：{execution_time:.4f} 秒")
# Out:
# 程式執行時間：0.0500 秒

# %% [markdown]
# ### 時間延遲

# %%
import time

print("開始倒數...")
for i in range(5, 0, -1):
    print(f"{i}...")
    time.sleep(1)  # 暫停1秒
print("時間到！🎉")
# Out:
# 開始倒數...
# 5...
# 4...
# 3...
# 2...
# 1...
# 時間到！🎉

# %% [markdown]
# ## 用 print + time 做出會動的動畫
#
# ### 跳動的心 💓

# %%
import time
import os

hearts = ["💜", "💙", "💚", "💛", "❤️"]

for i in range(20):
    os.system('clear')  # Windows用 'cls'
    heart = hearts[i % len(hearts)]
    print(f"\n\n      {heart} Python {heart}")
    print("    學習程式好有趣！")
    time.sleep(0.5)
# Out:
#       💜 Python 💜
#     學習程式好有趣！
#
#
#       💙 Python 💙
#     學習程式好有趣！
#
#
#       💚 Python 💚
#     學習程式好有趣！
#
#
#       💛 Python 💛
#     學習程式好有趣！
#
#
#       ❤️ Python ❤️
#     學習程式好有趣！
#
#
#       💜 Python 💜
#     學習程式好有趣！
#
#
#       💙 Python 💙
#     學習程式好有趣！
#
#
#       💚 Python 💚
#     學習程式好有趣！
#
#
#       💛 Python 💛
#     學習程式好有趣！
#
#
#       ❤️ Python ❤️
#     學習程式好有趣！
#
#
#       💜 Python 💜
#     學習程式好有趣！
#
#
#       💙 Python 💙
#     學習程式好有趣！
#
#
#       💚 Python 💚
#     學習程式好有趣！
#
#
#       💛 Python 💛
#     學習程式好有趣！
#
#
#       ❤️ Python ❤️
#     學習程式好有趣！
#
#
#       💜 Python 💜
#     學習程式好有趣！
#
#
#       💙 Python 💙
#     學習程式好有趣！
#
#
#       💚 Python 💚
#     學習程式好有趣！
#
#
#       💛 Python 💛
#     學習程式好有趣！
#
#
#       ❤️ Python ❤️
#     學習程式好有趣！

# %% [markdown]
# ### 載入動畫

# %%
import time

def loading_animation():
    chars = "|/-\\"
    for i in range(20):
        print(f"\r載入中 {chars[i % len(chars)]}", end="")
        time.sleep(0.2)
    print("\r載入完成！✅")

loading_animation()
# Out:
# 載入完成！✅

# %% [markdown]
# ## 實例展示：ASCII小貓 🐱

# %%
import time

def draw_cat():
    cat = [
        "     /\\_/\\  ",
        "    ( o.o ) ",
        "     > ^ <  ",
    ]

    print("繪製小貓中...")
    for line in cat:
        print(line)
        time.sleep(0.5)

    print("\n🐱 可愛的ASCII小貓完成了！")

draw_cat()
# Out:
# 繪製小貓中...
#      /\_/\
#     ( o.o )
#      > ^ <
#
# 🐱 可愛的ASCII小貓完成了！

# %% [markdown]
# ### 會眨眼的小貓 😸

# %%
import time
import os

def blinking_cat():
    open_eyes = [
        "     /\\_/\\  ",
        "    ( o.o ) ",
        "     > ^ <  "
    ]

    closed_eyes = [
        "     /\\_/\\  ",
        "    ( -.- ) ",
        "     > ^ <  "
    ]

    for _ in range(5):
        os.system('clear')  # Windows用 'cls'
        for line in open_eyes:
            print(line)
        time.sleep(1)

        os.system('clear')
        for line in closed_eyes:
            print(line)
        time.sleep(0.3)

blinking_cat()
# Out:
#      /\_/\
#     ( o.o )
#      > ^ <
#      /\_/\
#     ( -.- )
#      > ^ <
#      /\_/\
#     ( o.o )
#      > ^ <
#      /\_/\
#     ( -.- )
#      > ^ <
#      /\_/\
#     ( o.o )
#      > ^ <
#      /\_/\
#     ( -.- )
#      > ^ <
#      /\_/\
#     ( o.o )
#      > ^ <
#      /\_/\
#     ( -.- )
#      > ^ <
#      /\_/\
#     ( o.o )
#      > ^ <
#      /\_/\
#     ( -.- )
#      > ^ <
